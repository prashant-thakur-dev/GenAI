# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model="arcee-ai/trinity-large-preview:free",
    openai_api_base="https://openrouter.ai/api/v1",
    openai_api_key=os.getenv("OPENAI_API_KEY"),
    streaming=True
)

question = "explain gen ai in detail"

res = llm.stream(question)
for chunk in res:
    print(chunk.content, end="")
# Out:
# Generative AI refers to artificial intelligence systems that can create new content—such as text, images, audio, video, or even code—based on patterns learned from existing data. Unlike traditional AI, which focuses on recognizing or classifying data, generative AI produces original outputs that mimic human creativity. Here's a detailed breakdown:
#
# ---
#
# ### **How Generative AI Works**
# Generative AI models are trained on large datasets to learn patterns, structures, and relationships within the data. They use advanced techniques like **deep learning** and **neural networks** to generate new content. The most common architectures include:
#
# 1. **Generative Adversarial Networks (GANs)**: Two neural networks (a generator and a discriminator) compete to create realistic outputs. GANs are widely used for generating images and videos.
# 2. **Variational Autoencoders (VAEs)**: These models learn to compress and reconstruct data, enabling them to generate new variations.
# 3. **Transformers**: These models, like GPT (Generative Pre-trained Transformer), use attention mechanisms to process and generate sequential data, such as text.
#
# ---
#
# ### **Types of Generative AI**
# Generative AI can be applied to various domains:
#
# 1. **Text Generation**: Models like GPT-3, GPT-4, and ChatGPT generate human-like text, answer questions, or write stories.
# 2. **Image Generation**: Tools like DALL-E, MidJourney, and Stable Diffusion create images from text prompts.
# 3. **Audio Generation**: AI can generate music, voiceovers, or sound effects (e.g., Jukebox, WaveNet).
# 4. **Video Generation**: AI can create or edit videos, such as deepfakes or animations.
# 5. **Code Generation**: Tools like GitHub Copilot assist in writing code.
# 6. **3D Model Generation**: AI can generate 3D models for gaming or design.
#
# ---
#
# ### **Applications of Generative AI**
# Generative AI has a wide range of applications across industries:
#
# 1. **Content Creation**: Writing articles, generating marketing copy, or creating social media posts.
# 2. **Art and Design**: Generating unique artwork, logos, or product designs.
# 3. **Entertainment**: Creating music, scripts, or special effects in movies and games.
# 4. **Healthcare**: Generating synthetic medical data for research or drug discovery.
# 5. **Education**: Creating personalized learning materials or tutoring systems.
# 6. **Business**: Automating customer service, generating reports, or simulating scenarios.
#
# ---
#
# ### **Benefits of Generative AI**
# 1. **Efficiency**: Automates repetitive tasks, saving time and resources.
# 2. **Creativity**: Generates novel ideas or designs that humans might not think of.
# 3. **Personalization**: Creates tailored content for individual users.
# 4. **Scalability**: Can produce large volumes of content quickly.
#
# ---
#
# ### **Challenges and Ethical Concerns**
# 1. **Bias**: AI models can inherit biases from training data, leading to unfair or harmful outputs.
# 2. **Misuse**: Generative AI can be used to create deepfakes, spread misinformation, or generate harmful content.
# 3. **Intellectual Property**: Questions arise about ownership of AI-generated content.
# 4. **Job Displacement**: Automation may replace certain creative or analytical roles.
# 5. **Quality Control**: Ensuring the accuracy and relevance of generated content can be challenging.
#
# ---
#
# ### **Future of Generative AI**
# The field is rapidly evolving, with advancements in model efficiency, interpretability, and ethical safeguards. Future developments may include:
#
# 1. **Better Integration**: Seamless integration of generative AI into everyday tools and workflows.
# 2. **Improved Ethics**: Stronger frameworks to address bias, misuse, and accountability.
# 3. **Multimodal Models**: AI that can generate and understand multiple types of data (e.g., text, images, and audio) simultaneously.
# 4. **Democratization**: Making generative AI accessible to a broader audience.
#
# ---
#
# Generative AI is a transformative technology with immense potential to reshape industries and creative processes. However, its responsible development and use are critical to maximizing its benefits while mitigating risks.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(
    model="tngtech/deepseek-r1t2-chimera:free",
    openai_api_base="https://openrouter.ai/api/v1",
    openai_api_key=os.getenv("OPENAI_API_KEY")
)

# %%
question = "who is pm of india"

# %%
res = llm.invoke(question)
res.content
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 res = llm.invoke(question)
#       2 res.content
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1121, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1112 @override
#    1113 def generate_prompt(
#    1114     self,
#    (...)   1118     **kwargs: Any,
#    1119 ) -> LLMResult:
#    1120     prompt_messages = [p.to_messages() for p in prompts]
# -> 1121     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\langchain_core\language_models\chat_models.py:931, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     928 for i, m in enumerate(input_messages):
#     929     try:
#     930         results.append(
# --> 931             self._generate_with_cache(
#     932                 m,
#     933                 stop=stop,
#     934                 run_manager=run_managers[i] if run_managers else None,
#     935                 **kwargs,
#     936             )
#     937         )
#     938     except BaseException as e:
#     939         if run_managers:
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1225, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1223     result = generate_from_stream(iter(chunks))
#    1224 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1225     result = self._generate(
#    1226         messages, stop=stop, run_manager=run_manager, **kwargs
#    1227     )
#    1228 else:
#    1229     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\langchain_openai\chat_models\base.py:1386, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1384     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1385         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1386     raise e
#    1387 if (
#    1388     self.include_response_headers
#    1389     and raw_response is not None
#    1390     and hasattr(raw_response, "headers")
#    1391 ):
#    1392     generation_info = {"headers": dict(raw_response.headers)}
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\langchain_openai\chat_models\base.py:1381, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1374         return _construct_lc_result_from_responses_api(
#    1375             response,
#    1376             schema=original_schema_obj,
#    1377             metadata=generation_info,
#    1378             output_version=self.output_version,
#    1379         )
#    1380     else:
# -> 1381         raw_response = self.client.with_raw_response.create(**payload)
#    1382         response = raw_response.parse()
#    1383 except Exception as e:
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\sem7\New folder\GenAI\env\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'User not found.', 'code': 401}}
