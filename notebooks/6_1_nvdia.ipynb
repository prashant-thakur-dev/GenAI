# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

# %%
llm = ChatNVIDIA(model="qwen/qwen2.5-coder-32b-instruct")

# %%
result = llm.stream("Write a ballad about LangChain.")
for chunk in result:
    print(chunk.content,end="")
# Out:
# In lands of code and dreams so vast,
# Where strings and logs entwined and crossed,
# Lived a library oh so grand,
# A wondrous tool, LangChain planned.
#
# Through fields of data wild and free,
# This chain would wander, set to be
# A bard of bytes, knowledge to sing,
# From document stores through code's design.
#
# With prompt and passage, query and quest,
# LangChain weaved its magic best.
# It summoned facts from depths so wide,
# Then with beauty spun them, side by side.
#
# In offices where wizardry sprang,
# From brainstorming to AI's dancing,
# LangChain danced and dreamed and played,
# Linking thoughts and ideas, making friends arrayed.
#
# From ancient texts to current chat,
# Its wisdom vast, a curious fact.
# It built bridges, paths drew in minds,
# Cherishing each bit of learning kind.
#
# Oh LangChain, a tale of tech,
# Through data's oceans, its spirit set.
# Forever bound, in schematics and flow,
# LangChain sings its notes of knowledge, let it grow!
#
# So here's to you, LangChain so great,
# In chains of code, your journey well-begun and fate.
# May truth and queries, and friendly lighthearted play,
# Be the winds of change, as kernels turn from day to day.
