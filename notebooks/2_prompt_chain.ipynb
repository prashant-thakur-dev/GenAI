# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# %%
prompts = [
    {"role":"system", "content":"you are a java developer."},
    {"role":"user", "content":"difference between map and set."},
]

res = model.invoke(prompts)
print(res.content)
# Out:
# In Java, both `Map` and `Set` are part of the `java.util` package and are fundamental interfaces in the Collections Framework, but they serve very different purposes and have distinct characteristics.
#
# Here's a detailed breakdown of their differences:
#
# ---
#
# ### Core Difference
#
# *   **Set:** A collection that stores **unique elements**. It represents a mathematical set.
# *   **Map:** A collection that stores **key-value pairs**, where each key is unique. It represents an association or a dictionary.
#
# ---
#
# ### Comparison Table
#
# | Feature              | `Set`                                          | `Map`                                                               |
# | :------------------- | :--------------------------------------------- | :------------------------------------------------------------------ |
# | **Primary Purpose**  | Store a collection of unique elements.         | Store associations between unique keys and values.                  |
# | **Structure**        | Contains individual elements. (`[A, B, C]`)    | Contains key-value pairs. (`{K1=V1, K2=V2}`)                       |
# | **Uniqueness**       | Elements must be unique.                       | Keys must be unique. Values can be duplicated.                      |
# | **Interface**        | `java.util.Set` (extends `java.util.Collection`) | `java.util.Map` (a separate top-level interface, does **not** extend `Collection`) |
# | **Adding Elements**  | `add(E element)`                               | `put(K key, V value)`                                               |
# | **Retrieving Data**  | Check for existence: `contains(Object element)`. Iterate. No direct "get by index/key". | Retrieve value by key: `get(Object key)`.                         |
# | **Iteration**        | Iterate over elements directly.                | Iterate over keys (`keySet()`), values (`values()`), or key-value pairs (`entrySet()`). |
# | **Typical Use Cases** | - Storing unique items (e.g., unique user IDs).<br>- Removing duplicates from a list.<br>- Checking for membership efficiently. | - Dictionary (word to definition).<br>- Configuration settings (property name to value).<br>- Object properties (field name to value).<br>- Caching data. |
# | **Analogy**          | A bag of unique items (e.g., a collection of unique stamps). | A dictionary or phone book (word-definition, name-number).        |
#
# ---
#
# ### Detailed Explanation
#
# 1.  **Fundamental Structure:**
#     *   **Set:** Imagine a bag where you can only put distinct items. If you try to put an item that's already there, nothing changes. The order of items is generally not guaranteed (e.g., `HashSet`), though some implementations like `LinkedHashSet` maintain insertion order and `TreeSet` maintains natural ordering.
#     *   **Map:** Imagine a dictionary. Each word (key) has a unique definition (value). You can't have two identical words with different definitions in the same dictionary. You use the word to look up its definition.
#
# 2.  **Uniqueness:**
#     *   **Set:** The defining characteristic. If you add an element that is already present (based on its `equals()` method), the `add()` method will return `false` and the set will remain unchanged.
#     *   **Map:** Uniqueness applies to the **keys**. If you `put()` a new value with an existing key, the old value associated with that key will be replaced. The `put()` method will return the old value. Values themselves are *not* required to be unique; multiple keys can map to the same value.
#
# 3.  **Interface Hierarchy:**
#     *   **Set:** Extends the `Collection` interface. This means it inherits methods like `add()`, `remove()`, `contains()`, `size()`, `isEmpty()`, etc., which are common to all collections of individual elements.
#     *   **Map:** Is a standalone interface. It does *not* extend `Collection`. This is because a `Map` doesn't represent a collection of individual elements; it represents a collection of *associations* (key-value pairs). You can, however, get collections from a Map (e.g., `keySet()`, `values()`, `entrySet()`).
#
# 4.  **Adding and Retrieving Data:**
#     *   **Set:** You `add()` an element. To check if an element exists, you use `contains()`. You cannot directly "get" an element from a Set by an index or key; you iterate through it to access its elements.
#     *   **Map:** You `put(key, value)` to add an association. To retrieve a value, you use `get(key)`.
#
# 5.  **Common Implementations:**
#     *   **Set:**
#         *   `HashSet`: Uses a hash table for storage. Offers constant-time performance for basic operations (add, remove, contains) assuming good hash functions. No guaranteed order.
#         *   `LinkedHashSet`: Maintains insertion order. Slightly slower than `HashSet`.
#         *   `TreeSet`: Stores elements in a sorted order (natural ordering or custom `Comparator`). Slower than `HashSet` for basic operations (logarithmic time).
#     *   **Map:**
#         *   `HashMap`: Uses a hash table. Offers constant-time performance for basic operations (put, get, remove) assuming good hash functions. No guaranteed order.
#         *   `LinkedHashMap`: Maintains insertion order.
#         *   `TreeMap`: Stores entries in a sorted order based on the keys (natural ordering or custom `Comparator`). Slower than `HashMap` for basic operations (logarithmic time).
#
# ---
#
# ### When to Use Which
#
# *   **Use a `Set` when:**
#     *   You need to store a collection of items where each item must be unique.
#     *   You want to efficiently check for the presence of an item.
#     *   You need to filter out duplicate items from another collection.
#     *   The order of elements is not critical (unless using `LinkedHashSet` or `TreeSet`).
#
#     *Example:* Storing all the unique words found in a document.
#
# *   **Use a `Map` when:**
#     *   You need to store data as key-value pairs.
#     *   You need to retrieve a value based on a unique key.
#     *   You want to associate information (a value) with an identifier (a key).
#
#     *Example:* Storing user profiles where the username (key) maps to a `User` object (value).
#
# ---
#
# ### Code Examples
#
# #### Set Example
#
# ```java
# import java.util.HashSet;
# import java.util.Set;
#
# public class SetExample {
#     public static void main(String[] args) {
#         Set<String> uniqueNames = new HashSet<>();
#
#         // Add elements
#         uniqueNames.add("Alice");
#         uniqueNames.add("Bob");
#         uniqueNames.add("Charlie");
#         uniqueNames.add("Alice"); // Duplicate, will not be added
#
#         System.out.println("Set elements: " + uniqueNames); // Output: [Bob, Alice, Charlie] (order may vary for HashSet)
#         System.out.println("Size of set: " + uniqueNames.size()); // Output: 3
#
#         // Check for existence
#         System.out.println("Contains 'Bob'? " + uniqueNames.contains("Bob"));     // Output: true
#         System.out.println("Contains 'David'? " + uniqueNames.contains("David")); // Output: false
#
#         // Iterate
#         System.out.println("Iterating through set:");
#         for (String name : uniqueNames) {
#             System.out.println(name);
#         }
#     }
# }
# ```
#
# #### Map Example
#
# ```java
# import java.util.HashMap;
# import java.util.Map;
#
# public class MapExample {
#     public static void main(String[] args) {
#         Map<String, Integer> studentScores = new HashMap<>();
#
#         // Add key-value pairs
#         studentScores.put("Alice", 95);
#         studentScores.put("Bob", 88);
#         studentScores.put("Charlie", 92);
#         studentScores.put("Alice", 98); // Key "Alice" already exists, value will be updated
#
#         System.out.println("Map entries: " + studentScores); // Output: {Bob=88, Alice=98, Charlie=92} (order may vary for HashMap)
#         System.out.println("Size of map: " + studentScores.size()); // Output: 3
#
#         // Retrieve value by key
#         System.out.println("Alice's score: " + studentScores.get("Alice"));     // Output: 98
#         System.out.println("David's score: " + studentScores.get("David"));     // Output: null (key not found)
#
#         // Iterate over keys
#         System.out.println("\nIterating over keys:");
#         for (String name : studentScores.keySet()) {
#             System.out.println("Student: " + name);
#         }
#
#         // Iterate over values
#         System.out.println("\nIterating over values:");
#         for (Integer score : studentScores.values()) {
#             System.out.println("Score: " + score);
#         }
#
#         // Iterate over key-value pairs (entries)
#         System.out.println("\nIterating over entries:");
#         for (Map.Entry<String, Integer> entry : studentScores.entrySet()) {
#             System.out.println(entry.getKey() + " -> " + entry.getValue());
#         }
#     }
# }
# ```
#
# ---
#
# In summary, `Set` is for managing distinct items, while `Map` is for managing associations between distinct keys and their corresponding values. Choosing between them depends entirely on the nature of the data you need to store and how you intend to access it.

# %% [markdown]
# ### prompt templates or Dynamic prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")
out = StrOutputParser()

# %%
def transform_case(result:str):
    return result.upper()

# %%
prompt = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"you are a {language} translator, translate the input."},
    {"role":"user", "content":"{query}"},
])

# %%
# final_prompt = prompt.format_messages(language = "Hinglish", query = "i love java and python")
# res = llm.invoke(final_prompt)
# print(res.content)
# Out:
# Mujhe Java aur Python pasand hai.

# %% [markdown]
# ### Chains = Runnable

# %%
# res = llm.invoke(prompt.invoke({"language": "hindi", "query":"i love you"}))
# print(res.content)
# Out:
# "I love you" का हिंदी अनुवाद है:
#
# *   **मैं तुमसे प्यार करता हूँ।** (अगर कहने वाला पुरुष है)
# *   **मैं तुमसे प्यार करती हूँ।** (अगर कहने वाली महिला है)
#
# (आप "तुमसे" की जगह "आपसे" का प्रयोग कर सकते हैं यदि आप जिसे कह रहे हैं उसके प्रति अधिक औपचारिकता या सम्मान दिखाना चाहते हैं।)

# %%
chains = prompt | llm | out | transform_case

# %%
res = chains.invoke({"language": "hinglish", "query":"i love you"})
res
# Out:
# 'HERE ARE A FEW WAYS TO SAY "I LOVE YOU" IN HINGLISH, DEPENDING ON THE CONTEXT AND SPEAKER\'S GENDER:\n\n1.  **"I LOVE YOU"** (OFTEN USED DIRECTLY AS IS, AS IT\'S UNIVERSALLY UNDERSTOOD AND INTEGRATED INTO HINGLISH CONVERSATIONS).\n2.  **"MAIN TUMHE LOVE KARTA HOON."** (IF A MALE SPEAKER)\n3.  **"MAIN TUMHE LOVE KARTI HOON."** (IF A FEMALE SPEAKER)\n\nYOU CAN ALSO USE THE MORE PURE HINDI VERSIONS, WHICH ARE VERY COMMON AND UNDERSTOOD IN HINGLISH CONTEXTS:\n\n*   **"MAIN TUMSE PYAAR KARTA HOON."** (IF A MALE SPEAKER)\n*   **"MAIN TUMSE PYAAR KARTI HOON."** (IF A FEMALE SPEAKER)'
